# %%
import gcsfs
import pandas as pd
gcs = gcsfs.GCSFileSystem()

# %%
with gcs.open('dask-data/scaling-data.csv') as f:
    df = pd.read_csv(f)
    
df
# Out:
#     collection                          name    n     unit   duration  \
# 0       arrays         blockwise 100ms tasks    2     MB/s   0.930781
# 1       arrays         blockwise 100ms tasks    4     MB/s   0.847067
# 2       arrays         blockwise 100ms tasks    8     MB/s   1.053046
# 3       arrays         blockwise 100ms tasks   16     MB/s   0.967746
# 4       arrays         blockwise 100ms tasks   32     MB/s   1.113454
# 5       arrays         blockwise 100ms tasks   64     MB/s   0.967302
# 6       arrays         blockwise 100ms tasks  128     MB/s   1.289514
# 7       arrays         blockwise 100ms tasks  256     MB/s   1.730550
# 8       arrays         blockwise 100ms tasks  512     MB/s   6.030538
# 9       arrays                 create random    2     MB/s   0.584174
# 10      arrays                 create random    4     MB/s   0.655029
# 11      arrays                 create random    8     MB/s   0.721304
# 12      arrays                 create random   16     MB/s   0.664351
# 13      arrays                 create random   32     MB/s   0.718007
# 14      arrays                 create random   64     MB/s   0.738002
# 15      arrays                 create random  128     MB/s   1.200436
# 16      arrays                 create random  256     MB/s   2.564872
# 17      arrays                 create random  512     MB/s   1.880598
# 18      arrays       elementwise computation    2     MB/s   2.708794
# 19      arrays       elementwise computation    4     MB/s   2.908163
# 20      arrays       elementwise computation    8     MB/s   3.580060
# 21      arrays       elementwise computation   16     MB/s   3.964876
# 22      arrays       elementwise computation   32     MB/s   5.441955
# 23      arrays       elementwise computation   64     MB/s   7.383476
# 24      arrays       elementwise computation  128     MB/s  13.116995
# 25      arrays       elementwise computation  256     MB/s  21.965428
# 26      arrays       elementwise computation  512     MB/s  42.592467
# 27      arrays  nearest neighbor 100ms tasks    2     MB/s   1.236899
# 28      arrays  nearest neighbor 100ms tasks    4     MB/s   1.160823
# 29      arrays  nearest neighbor 100ms tasks    8     MB/s   1.509198
# ..         ...                           ...  ...      ...        ...
# 249      tasks             task map 1s tasks  128  tasks/s   5.590187
# 250      tasks             task map 1s tasks  256  tasks/s   5.644582
# 251      tasks             task map 1s tasks  512  tasks/s   7.549867
# 252      tasks           task map fast tasks    2  tasks/s   0.221133
# 253      tasks           task map fast tasks    4  tasks/s   0.241904
# 254      tasks           task map fast tasks    8  tasks/s   0.486054
# 255      tasks           task map fast tasks   16  tasks/s   0.800579
# 256      tasks           task map fast tasks   32  tasks/s   1.796089
# 257      tasks           task map fast tasks   64  tasks/s   3.346050
# 258      tasks           task map fast tasks  128  tasks/s   6.896783
# 259      tasks           task map fast tasks  256  tasks/s  14.315529
# 260      tasks           task map fast tasks  512  tasks/s  29.077214
# 261      tasks    tree reduction 100ms tasks    2  tasks/s   6.856049
# 262      tasks    tree reduction 100ms tasks    4  tasks/s   7.081078
# 263      tasks    tree reduction 100ms tasks    8  tasks/s   7.219373
# 264      tasks    tree reduction 100ms tasks   16  tasks/s   7.429270
# 265      tasks    tree reduction 100ms tasks   32  tasks/s   7.793831
# 266      tasks    tree reduction 100ms tasks   64  tasks/s   8.285013
# 267      tasks    tree reduction 100ms tasks  128  tasks/s   8.970450
# 268      tasks    tree reduction 100ms tasks  256  tasks/s  12.109690
# 269      tasks    tree reduction 100ms tasks  512  tasks/s  18.223943
# 270      tasks     tree reduction fast tasks    2  tasks/s   0.202223
# 271      tasks     tree reduction fast tasks    4  tasks/s   0.294252
# 272      tasks     tree reduction fast tasks    8  tasks/s   0.505821
# 273      tasks     tree reduction fast tasks   16  tasks/s   0.864661
# 274      tasks     tree reduction fast tasks   32  tasks/s   1.395554
# 275      tasks     tree reduction fast tasks   64  tasks/s   2.916794
# 276      tasks     tree reduction fast tasks  128  tasks/s   5.950359
# 277      tasks     tree reduction fast tasks  256  tasks/s  11.853272
# 278      tasks     tree reduction fast tasks  512  tasks/s  25.379409
#
#              rate
# 0      429.738441
# 1      944.435197
# 2     1519.373375
# 3     3306.651083
# 4     5747.768011
# 5    13232.684357
# 6    19852.058765
# 7    29585.964835
# 8    16980.218490
# 9      684.713900
# 10    1221.319419
# 11    2218.161714
# 12    4816.727556
# 13    8913.387113
# 14   17344.136192
# 15   21325.182436
# 16   19962.007739
# 17   54450.695152
# 18     147.664339
# 19     275.087715
# 20     446.911371
# 21     807.087044
# 22    1176.025319
# 23    1733.600921
# 24    1951.629145
# 25    2330.935700
# 26    2404.177413
# 27     323.383141
# 28     689.166299
# 29    1060.145264
# ..            ...
# 249     91.589068
# 250    181.412908
# 251    271.263068
# 252   1808.870110
# 253   3307.103271
# 254   3291.817309
# 255   3997.107929
# 256   3563.297941
# 257   3825.405776
# 258   3711.875589
# 259   3576.535636
# 260   3521.657944
# 261     37.339291
# 262     72.305377
# 263    141.840563
# 264    275.666383
# 265    525.543849
# 266    988.773376
# 267   1826.441178
# 268   2705.932256
# 269   3596.148117
# 270   1265.927313
# 271   1740.005646
# 272   2024.432563
# 273   2368.557067
# 274   2935.035983
# 275   2808.563041
# 276   2753.447264
# 277   2764.468701
# 278   2582.250800
#
# [279 rows x 6 columns]

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import Row, Column, gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="051394a1-e58a-4bb0-9e61-336b796ef193">Loading BokehJS ...</span>
#     </div>

# %%
def scaling_plot(part, axis_type='linear'):
    row = part.iloc[0]
    title = (row['collection'] + ': ' + row['name']).title().replace('0M', '0m').replace('1S', '1s')

    fig = figure(title=title, sizing_mode='scale_width', x_axis_type=axis_type, y_axis_type=axis_type)
    fig.line(x=part.n, y=part.rate)
    fig.circle(x=part.n, y=part.rate)
    fig.xaxis.axis_label = 'cores'
    fig.yaxis.axis_label = row['unit']
    fig.x_range.start = 0
    fig.y_range.start = 0

    # Add in perfect scaling line
    y_end = fig.y_range.end
    mn = part.n.min()
    mx = part.n.max()
    slope = part[part.n == mn].iloc[0]['rate'] / mn
    fig.line(x=[0, mx], y=[0, slope * mx], color='gray', line_dash='dashed')
    fig.y_range.end = part.rate.max()
    
    fig.xaxis.ticker = part.n

    return fig

# %%
df2 = df.groupby(['collection', 'name'])['collection', 'name', 'n', 'rate', 'unit'].apply(scaling_plot)
df2
# Out:
# collection  name
# arrays      blockwise 100ms tasks                 Figure(id='bcca8fc0-7fe6-458b-9c19-6cb29d44131...
#             create random                         Figure(id='d8bcdc1e-f3d9-42c6-94ce-75464f676e8...
#             elementwise computation               Figure(id='617352a4-ce31-45bd-ae48-9f273d04978...
#             nearest neighbor 100ms tasks          Figure(id='c533f293-6da4-4fcd-9981-cd4a228fcec...
#             nearest neighbor fast tasks           Figure(id='181550ff-8183-4494-899d-9e7b16db240...
#             random access                         Figure(id='e68756de-ce1c-440f-b554-3910b12598f...
#             rechunk large                         Figure(id='98b62a74-238a-4dbb-a00f-aac75621172...
#             rechunk small                         Figure(id='2a98d534-b0e7-4c5a-bd28-32d5aae870f...
#             reduction                             Figure(id='0834997a-d482-4e1c-a0cf-8c980bd5da8...
#             reduction along axis                  Figure(id='60a7509c-35e7-46cc-b547-2072701d7fc...
#             transpose addition                    Figure(id='f4429e42-0003-4c4a-b53f-d32be1fe2a7...
# dataframes  arithmetic                            Figure(id='bb3cdc16-306a-4eca-8bea-d78af7d011d...
#             blockwise 100ms tasks                 Figure(id='6c694c69-c303-49b3-8b45-b3aaa65486e...
#             create random                         Figure(id='7fa63a9f-6a95-4d73-a8dc-a138c0e305d...
#             dataframe reduction                   Figure(id='3b2726ce-eefe-42f8-8771-fd816e2065c...
#             groupby apply (full shuffle)          Figure(id='fe8d51a6-bedf-421b-abd7-3c1c36d5eeb...
#             groupby reduction                     Figure(id='345dd894-9c0e-4029-a5f3-93a7bcf4646...
#             random access                         Figure(id='52e54ceb-d341-4a3f-a7ec-927da4854b5...
#             rolling aggregations                  Figure(id='d9b90423-449b-4214-8a57-5f4c2834716...
#             series reduction                      Figure(id='6a1b3578-4c22-4fcf-99c9-aaff125fc6e...
#             set index (full shuffle)              Figure(id='57ed361b-be6c-488d-938b-2c723fb1750...
# tasks       dynamic tree reduction 100ms tasks    Figure(id='e4df49b6-7857-4bfb-b716-fb3ddaed3f9...
#             dynamic tree reduction fast tasks     Figure(id='efb02e2b-e8e1-41e7-9146-b183ed9475f...
#             nearest neighbor 100ms tasks          Figure(id='3dfadbf7-7a01-41e6-a4e3-907cf0a6189...
#             nearest neighbor fast tasks           Figure(id='8e774f01-9d70-4656-a01f-71f1186dbda...
#             sequential                            Figure(id='c9d51a70-70c8-4b7b-b976-260fd0756c9...
#             task map 100ms tasks                  Figure(id='682118d9-44c2-4cd3-bd82-9716c23ec89...
#             task map 1s tasks                     Figure(id='504aa97b-a65b-470f-bf26-42d88766680...
#             task map fast tasks                   Figure(id='b2a2e084-afb3-4e2d-b29f-9802b4ddd34...
#             tree reduction 100ms tasks            Figure(id='ee7ad037-8c0a-4b84-baa0-77e64dff90b...
#             tree reduction fast tasks             Figure(id='5599840f-08e1-436d-afd9-0049ff7905f...
# dtype: object

# %%
names = ['task map 1s tasks', 'task map 100ms tasks', 'task map fast tasks',
         'tree reduction 100ms tasks', 'tree reduction fast tasks', 'sequential',
         'nearest neighbor 100ms tasks', 'nearest neighbor fast tasks', 
         'dynamic tree reduction 100ms tasks', 'dynamic tree reduction fast tasks']
from toolz import partition_all
L = df2.loc['tasks'].loc[names].values.tolist()
grid = list(partition_all(3, L))
# show(Column(*[Row(*g, sizing_mode='scale_width') for g in grid], sizing_mode='scale_width'))
show(gridplot(grid, sizing_mode='scale_width'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c661cb6d-99f2-4a6d-910a-9136181a2838"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c661cb6d-99f2-4a6d-910a-9136181a2838");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c661cb6d-99f2-4a6d-910a-9136181a2838");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c661cb6d-99f2-4a6d-910a-9136181a2838' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"00297a39-c3e7-45c2-ab4f-089cd672569b":{"roots":{"references":[{"attributes":{"children":[{"id":"3dfadbf7-7a01-41e6-a4e3-907cf0a6189b","subtype":"Figure","type":"Plot"},{"id":"8e774f01-9d70-4656-a01f-71f1186dbdaa","subtype":"Figure","type":"Plot"},{"id":"e4df49b6-7857-4bfb-b716-fb3ddaed3f9f","subtype":"Figure","type":"Plot"}],"sizing_mode":"scale_width"},"id":"19a01e94-dff3-4380-8c07-23db3aed698e","type":"Row"},{"attributes":{"below":[{"id":"34f2c6be-0a7e-42a3-ac1c-a645d491bc2f","type":"LinearAxis"}],"left":[{"id":"dec00b42-1fec-4d25-ac74-8ce35a425477","type":"LinearAxis"}],"renderers":[{"id":"34f2c6be-0a7e-42a3-ac1c-a645d491bc2f","type":"LinearAxis"},{"id":"121e6cce-e31f-4d54-9459-99c311657d7c","type":"Grid"},{"id":"dec00b42-1fec-4d25-ac74-8ce35a425477","type":"LinearAxis"},{"id":"c23a6055-050b-4b5f-a996-208d4c342352","type":"Grid"},{"id":"e8b1d38b-40dd-4247-a518-a2c9f3cf2922","type":"BoxAnnotation"},{"id":"bd16a269-0d37-4dcf-ae5b-65b1b51853ea","type":"GlyphRenderer"},{"id":"bd56c7f7-68b4-41f7-888a-22ce9db07602","type":"GlyphRenderer"},{"id":"38e9ba3b-16b9-4b06-aab0-1f7ba9e9ab8d","type":"GlyphRenderer"}],"sizing_mode":"scale_width","title":{"id":"01fde594-b679-4c0d-8759-991186b065fc","type":"Title"},"tool_events":{"id":"36925789-0077-4157-90a6-a3e45e628f3e","type":"ToolEvents"},"toolbar":{"id":"8e35d874-1e11-47fd-a355-6b14d1ffe823","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"17f71c0b-9181-448c-95d6-7a6e2ea219d2","type":"DataRange1d"},"x_scale":{"id":"c1d8ca52-7169-4595-954b-d9c8e74da6f1","type":"LinearScale"},"y_range":{"id":"c32974cf-763c-44ef-bbc2-f2640be785fa","type":"DataRange1d"},"y_scale":{"id":"9e8240a2-1b5c-4c5a-8cf3-32440343dd8b","type":"LinearScale"}},"id":"682118d9-44c2-4cd3-bd82-9716c23ec89d","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d16231ac-cf93-4685-baaf-04b418c052f9","type":"Line"},{"attributes":{"plot":null,"text":"Tasks: Task Map 100ms Tasks"},"id":"01fde594-b679-4c0d-8759-991186b065fc","type":"Title"},{"attributes":{"axis_label":"tasks/s","formatter":{"id":"b50d359f-da3a-4444-9a39-5c8953852c01","type":"BasicTickFormatter"},"plot":{"id":"682118d9-44c2-4cd3-bd82-9716c23ec89d","subtype":"Figure","type":"Plot"},"ticker":{"id":"53324647-f19a-4de3-ab8b-bf79bc399d5d","type":"BasicTicker"}},"id":"dec00b42-1fec-4d25-ac74-8ce35a425477","type":"LinearAxis"},{"attributes":{"children":[{"id":"ee7ad037-8c0a-4b84-baa0-77e64dff90b5","subtype":"Figure","type":"Plot"},{"id":"5599840f-08e1-436d-afd9-0049ff7905f8","subtype":"Figure","type":"Plot"},{"id":"c9d51a70-70c8-4b7b-b976-260fd0756c96","subtype":"Figure","type":"Plot"}],"sizing_mode":"scale_width"},"id":"a25b5039-57ae-4117-b0e7-55e990d49458","type":"Row"},{"attributes":{"ticks":[2,4,8,16,32,64,128,256,512]},"id":"7fe48d22-e98e-4b14-aec4-c62d2dafdb8e","type":"FixedTicker"},{"attributes":{"plot":{"id":"682118d9-44c2-4cd3-bd82-9716c23ec89d","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b26bf41-44f9-4f75-a040-a4836864e0b5","type":"BasicTicker"}},"id":"121e6cce-e31f-4d54-9459-99c311657d7c","type":"Grid"},{"attributes":{"plot":{"id":"682118d9-44c2-4cd3-bd82-9716c23ec89d","subtype":"Figure","type":"Plot"}},"id":"86fb5fc3-db79-4137-b8ec-35de7b4a6423","type":"WheelZoomTool"},{"attributes":{"axis_label":"tasks/s","formatter":{"id":"c00ff3ba-74ed-4496-9e40-01a0c2da7b06","type":"BasicTickFormatter"},"plot":{"id":"504aa97b-a65b-470f-bf26-42d887666809","subtype":"Figure","type":"Plot"},"ticker":{"id":"d6eaaf12-a65f-4ece-af91-8ac0cc64515f","type":"BasicTicker"}},"id":"68b38977-41a2-49f9-9289-ed2fafc291ce","type":"LinearAxis"},{"attributes":{"plot":{"id":"682118d9-44c2-4cd3-bd82-9716c23ec89d","subtype":"Figure","type":"Plot"}},"id":"f4a7fb31-62d7-4013-9e87-95b7a1065567","type":"SaveTool"},{"attributes":{"children":[{"id":"efb02e2b-e8e1-41e7-9146-b183ed9475f8","subtype":"Figure","type":"Plot"}],"sizing_mode":"scale_width"},"id":"1492af38-2e74-491e-aac4-87eb1 ...

# %%
names = ['create random', 'blockwise 100ms tasks', 'elementwise computation', 'reduction', 
         'reduction along axis', 'random access', 'transpose addition', 'rechunk large', 
         'nearest neighbor fast tasks', 'nearest neighbor 100ms tasks']
from toolz import partition_all
L = df2.loc['arrays'].loc[names].values.tolist()
grid = list(partition_all(3, L))
# show(Column(*[Row(*g, sizing_mode='scale_width') for g in grid], sizing_mode='scale_width'))
show(gridplot(grid, sizing_mode='scale_width'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5d975889-763d-43d5-8939-1fd4ef17fdd4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5d975889-763d-43d5-8939-1fd4ef17fdd4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5d975889-763d-43d5-8939-1fd4ef17fdd4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5d975889-763d-43d5-8939-1fd4ef17fdd4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"87bd99e7-1dfe-4e0c-8de8-d1923c84acc4":{"roots":{"references":[{"attributes":{"callback":null,"start":0},"id":"e83d8cbe-0760-46a9-bdc1-2baa423f2388","type":"DataRange1d"},{"attributes":{},"id":"6b7e028c-1e7f-40b4-8ad0-e4e795dbba31","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[2,4,8,16,32,64,128,256,512],"y":{"__ndarray__":"0/MveXGpk0CwnWLotLafQFzSKK/0oatAGQzzlhiFvEBuV2Og1WzIQFHk16Cvv8pAs1osroIq1EBv606nwBHYQN/8RMqJ9tlA","dtype":"float64","shape":[9]}}},"id":"760aa09c-f711-43bc-86ef-9aa3b5dc4187","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"19e680ec-3b5b-48bc-9ce9-759c2e87605a","type":"PanTool"},{"id":"3f02ad4d-5f70-400d-a0bb-09bc37e34188","type":"WheelZoomTool"},{"id":"7897919a-b747-42e6-87bc-c02d684e6d29","type":"BoxZoomTool"},{"id":"d2de0277-3338-4a67-8b61-6d87a7e49186","type":"SaveTool"},{"id":"6e1545e3-7bdf-45b6-9716-3a7f64e904f4","type":"ResetTool"},{"id":"ac4c6a1f-afca-46a1-92a3-d1df4604bf03","type":"HelpTool"}]},"id":"96e6c30d-5fcd-41e2-833c-b22d02f2a2a7","type":"Toolbar"},{"attributes":{},"id":"3c3f11b0-1620-4ebf-8eb5-866ab7f72c31","type":"BasicTickFormatter"},{"attributes":{},"id":"4782ba70-7d0b-44d2-8492-f4e6ba904a1f","type":"LinearScale"},{"attributes":{"ticks":[2,4,8,16,32,64,128,256,512]},"id":"41562129-ca51-40a8-9956-a2d3989e0657","type":"FixedTicker"},{"attributes":{"callback":null,"end":860.5686440460619,"start":0},"id":"dfee65b8-1dc3-4869-be38-8a0fd7d307e0","type":"DataRange1d"},{"attributes":{},"id":"d106bd93-1e7a-4f02-b44b-f7aa235811d9","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ad11e272-5705-4a3d-93f5-f4043fb95463","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d56ce35-c1f7-4980-89d0-da35d252e58c","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[2,4,8,16,32,64,128,256,512],"y":{"__ndarray__":"txeRHSzYhUCjQkyym/ODQDXnP5WM5IpAL2chJm3jhEB0ZkdqW+WBQI2SGi6KzoBAUViGGKc/hEDneAuUg4eCQAnnNrBvOH1A","dtype":"float64","shape":[9]}}},"id":"7cd710b6-c26f-4536-84a1-bebbb06f9418","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"e68756de-ce1c-440f-b554-3910b12598f0","subtype":"Figure","type":"Plot"}},"id":"19e680ec-3b5b-48bc-9ce9-759c2e87605a","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e36d627-af16-41a0-913c-2a8753d43cec","type":"Line"},{"attributes":{"plot":{"id":"e68756de-ce1c-440f-b554-3910b12598f0","subtype":"Figure","type":"Plot"}},"id":"3f02ad4d-5f70-400d-a0bb-09bc37e34188","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"ad11e272-5705-4a3d-93f5-f4043fb95463","type":"BoxAnnotation"},"plot":{"id":"e68756de-ce1c-440f-b554-3910b12598f0","subtype":"Figure","type":"Plot"}},"id":"7897919a-b747-42e6-87bc-c02d684e6d29","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"e68756de-ce1c-440f-b554-3910b12598f0","subtype":"Figure","type":"Plot"}},"id":"d2de0277-3338-4a67-8b61-6d87a7e49186","type":"SaveTool"},{"attributes":{"plot":{"id":"e68756de-ce1c-440f-b554-3910b12598f0","subtype":"Figure","type":"Plot"}},"id":"6e1545e3-7bdf-45b6-9716-3a7f64e904f4","type":"ResetTool"},{"attributes":{"plot":{"id":"e68756de-ce1c-440f-b554-3910b12598f0","subtype":"Figure","type":"Plot"}},"id":"ac4c6a1f-afca-46a1-92a3-d1df4604bf03","type":"HelpTool"},{"attributes":{},"id":"e7fe49f0-beb1-476a-a157-ba95dd1dbbf5","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"98b62a74-238a-4dbb-a00f-aac75621172b","subtype":"Figure","type":"Plot"}},"id":"a9385afc-5255-4aa4-b195-c120 ...

# %%
names = ['task map 1s tasks', 'task map 100ms tasks', 'task map fast tasks',
         'tree reduction 100ms tasks', 'tree reduction fast tasks', 'sequential',
         'nearest neighbor 100ms tasks', 'nearest neighbor fast tasks', 
         'dynamic tree reduction 100ms tasks', 'dynamic tree reduction fast tasks']
L = df2.loc['dataframes'].values.tolist()
grid = list(partition_all(3, L))
# show(Column(*[Row(*g, sizing_mode='scale_width') for g in grid], sizing_mode='scale_width'))
show(gridplot(grid, sizing_mode='scale_width'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="230dc4f6-f176-4918-8249-67b1f43d328c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("230dc4f6-f176-4918-8249-67b1f43d328c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("230dc4f6-f176-4918-8249-67b1f43d328c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '230dc4f6-f176-4918-8249-67b1f43d328c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"78d50318-56df-4cdd-9da1-4996189adf44":{"roots":{"references":[{"attributes":{"plot":{"id":"345dd894-9c0e-4029-a5f3-93a7bcf46465","subtype":"Figure","type":"Plot"}},"id":"a3084eae-14f8-40a6-a2e8-cdea87e17341","type":"SaveTool"},{"attributes":{},"id":"93e18ec4-19a2-4cb7-98ff-1eb95997bdb7","type":"LinearScale"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8dee8a2a-164d-470d-bad4-447cc84f85c8","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"00d20a6a-d390-4bb7-be34-b2dbd91f2b61","type":"BoxAnnotation"},{"attributes":{},"id":"063fcffc-348e-47c8-b4d4-89ca3fc9aa14","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"345dd894-9c0e-4029-a5f3-93a7bcf46465","subtype":"Figure","type":"Plot"}},"id":"79b9954a-df29-4214-9f20-2d086e367bdf","type":"ResetTool"},{"attributes":{"plot":{"id":"57ed361b-be6c-488d-938b-2c723fb17500","subtype":"Figure","type":"Plot"},"ticker":{"id":"958414cf-e735-4306-a8a8-feee501d64b0","type":"BasicTicker"}},"id":"55919bb7-d8aa-4298-97f6-cdbbd3e7edfa","type":"Grid"},{"attributes":{},"id":"0d50e4c4-05f8-4f06-9d8e-3c3e746d9c19","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"345dd894-9c0e-4029-a5f3-93a7bcf46465","subtype":"Figure","type":"Plot"}},"id":"de0cc529-bca4-414d-a5b7-97fb18aea7d4","type":"HelpTool"},{"attributes":{"data_source":{"id":"88d5b858-a176-4736-9729-29a2be87dac8","type":"ColumnDataSource"},"glyph":{"id":"3649cd4b-2784-4f21-8163-183fd6641c63","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"700e1093-77d2-42a1-b546-8577658e2b58","type":"Line"},"selection_glyph":null},"id":"4c4bb7b0-93ff-4267-9e08-e3f15a7e28df","type":"GlyphRenderer"},{"attributes":{"axis_label":"cores","formatter":{"id":"b8728014-c8a2-403c-bf54-7119e9d446e4","type":"BasicTickFormatter"},"plot":{"id":"57ed361b-be6c-488d-938b-2c723fb17500","subtype":"Figure","type":"Plot"},"ticker":{"id":"95b19d8e-a07b-489a-a04c-c11aecbb3838","type":"FixedTicker"}},"id":"6f608cf0-6d31-414e-bcd9-48e5e5c3f49f","type":"LinearAxis"},{"attributes":{"line_color":{"value":"gray"},"line_dash":[6],"x":{"field":"x"},"y":{"field":"y"}},"id":"f2d066ee-71ff-4cbf-8ec3-b94d4605a240","type":"Line"},{"attributes":{},"id":"6f61dfd0-846d-4f24-8ca3-672d108445b4","type":"BasicTickFormatter"},{"attributes":{},"id":"958414cf-e735-4306-a8a8-feee501d64b0","type":"BasicTicker"},{"attributes":{"axis_label":"MB/s","formatter":{"id":"4d2e2cdd-287e-428f-b9cc-2bddc03a3d31","type":"BasicTickFormatter"},"plot":{"id":"57ed361b-be6c-488d-938b-2c723fb17500","subtype":"Figure","type":"Plot"},"ticker":{"id":"5df91bff-df4d-4cab-92c5-0610d457ea2d","type":"BasicTicker"}},"id":"4bebd8d7-c2c8-443c-a5be-284cfe11dc25","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[2,4,8,16,32,64,128,256,512],"y":{"__ndarray__":"zYZNznMFgkAJVc0dH1aIQF6HLbAX8KBAEDiFMgobsEBOSk1Dh6G8QIcwzAFNYsdAkYwvunD+0kD/VzpMtBLaQNxDJJJ7lt5A","dtype":"float64","shape":[9]}}},"id":"72cb7cc9-75eb-4690-a607-aed1001ab3a0","type":"ColumnDataSource"},{"attributes":{},"id":"135e9c30-621d-426f-bc7f-bb1114c85e87","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"x":{"field":"x"},"y":{"field":"y"}},"id":"66f98e24-e75b-44bc-9425-facff4cbc8fc","type":"Line"},{"attributes":{},"id":"00bbe60a-5955-43ea-a353-eec6a3ce4003","type":"BasicTickFormatter"},{"attributes":{},"id":"5df91bff-df4d-4cab-92c5-0610d457ea2d","type":"BasicTicker"},{"attributes":{"axis_label":"bytes/s","formatter":{"id":"a99459fa-3ceb-444b-9677-b600bb558ad2","type":"BasicTickFormatter"},"plot":{"id":"52e54ceb-d341-4a3f-a7ec-927da4854b55","subtype":"Figure","type":"Plot"}, ...

# %%
from bokeh.palettes import viridis, Category10
from bokeh.models.widgets import Panel, Tabs

df3 = df.set_index(['collection', 'name'])[['n', 'rate', 'unit']]
n = df3.loc['tasks', 'task map 1s tasks'].n.values

colors = Category10[3]


def log_linear_plot(collection, names, title, legends=('100ms', '1us')):
    panels = []
    unit = df3.loc[collection, names[0]].iloc[0]['unit']
    
    for axis_type in ['log', 'linear']:
        fig = figure(title=title, # sizing_mode='scale_width', 
                     x_axis_type=axis_type, y_axis_type=axis_type, height=400, width=400)
        for i, name in enumerate(names):
            x = df3.loc[collection, name].n.values
            y = df3.loc[collection, name].rate.values
            fig.line(x=x, y=y, color=colors[i], legend=legends[i])
            fig.circle(x=x, y=y)

        for name in names:
            # Add in perfect scaling line
            x = df3.loc[collection, name].n.values
            y = df3.loc[collection, name].rate.values
            mn = x.min()
            mx = x.max()
            slope = y[0] / mn
            fig.line(x=[0, mx], y=[0, slope * mx], color='gray', line_dash='dashed')

        fig.y_range.end = max([df3.loc[collection, name].rate.max() for name in names])

        fig.xaxis.axis_label = 'cores'
        fig.yaxis.axis_label = unit
        fig.x_range.start = 0
        fig.y_range.start = 0

        fig.xaxis.ticker = x
        fig.legend.location = 'bottom_right'

        panel = Panel(child=fig, title=axis_type)
        panels.append(panel)

    tabs = Tabs(tabs=panels)
    return tabs

# %%
figures = {}

names = ['task map 1s tasks', 'task map 100ms tasks', 'task map fast tasks',]
legends = ['1s', '100ms', '1us']
fig = log_linear_plot('tasks', names, 'Tasks: Embarrassingly Parallel', legends)
figures['tasks-embarrasssing'] = fig

fig = log_linear_plot('tasks', ['tree reduction 100ms tasks', 'tree reduction fast tasks'], 'Tasks: Tree Reduction')
figures['tasks-reduction'] = fig

fig = log_linear_plot('tasks', ['nearest neighbor 100ms tasks', 'nearest neighbor fast tasks'], 'Tasks: Nearest Neighbor')
figures['tasks-nearest-neighbor'] = fig

fig = log_linear_plot('tasks', ['sequential'], 'Tasks: Sequential', legends=['fast'])
figures['tasks-sequential'] = fig

fig = log_linear_plot('tasks', ['dynamic tree reduction 100ms tasks', 'dynamic tree reduction fast tasks'], 'Tasks: Dynamic Reduction')
figures['tasks-dynamic-reduction'] = fig

L = [['tasks-embarrasssing', 'tasks-sequential'], ['tasks-nearest-neighbor', 'tasks-dynamic-reduction']]
figs = [[figures[k] for k in kk] for kk in L]
grid = gridplot(figs, sizing_mode='scale_width')
figures['tasks-grid'] = grid

# %%
show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fbdaa5ba-7d94-41f4-aad7-efa426d75155"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fbdaa5ba-7d94-41f4-aad7-efa426d75155");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fbdaa5ba-7d94-41f4-aad7-efa426d75155");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fbdaa5ba-7d94-41f4-aad7-efa426d75155' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"78136853-a7bf-47e4-9f4a-4e3f3dafa462":{"roots":{"references":[{"attributes":{"child":{"id":"b9760ac1-8aea-4392-ba3b-8c6daab6b8ee","subtype":"Figure","type":"Plot"},"title":"log"},"id":"94cf0c88-2683-48a8-89be-64622d87d921","type":"Panel"},{"attributes":{"axis_label":"cores","formatter":{"id":"2171c248-90a9-42bb-abf7-1dbd93fd4dcf","type":"BasicTickFormatter"},"plot":{"id":"df6b34a2-e392-424b-bb67-b032588bf567","subtype":"Figure","type":"Plot"},"ticker":{"id":"323b8206-7900-4f02-a161-e26e81c6607c","type":"FixedTicker"}},"id":"2ac00831-f3e1-4dab-90d4-69a75af7e81d","type":"LinearAxis"},{"attributes":{"line_color":{"value":"gray"},"line_dash":[6],"x":{"field":"x"},"y":{"field":"y"}},"id":"911291e4-1ff4-4f75-bfb4-591e7977a254","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[2,4,8,16,32,64,128,256,512],"y":{"__ndarray__":"YiGd3kr1M0C4DswHLGBDQAJlPBqPJVNAF1KOo6LJYkAH1cQ/wblxQALKM0XtrH9ADDdmn9fbi0DY4pMc/3KVQBZyRig+NJpA","dtype":"float64","shape":[9]}}},"id":"4f8a8e14-f455-4e9b-ab3b-5958846ef0a6","type":"ColumnDataSource"},{"attributes":{"ticker":null},"id":"e668922f-19c9-4281-ab6e-e0b709aff69d","type":"LogTickFormatter"},{"attributes":{"label":{"value":"100ms"},"renderers":[{"id":"4089741c-18bb-44cd-8572-9431b1b45303","type":"GlyphRenderer"}]},"id":"2f319a89-a0a3-4b89-bcc1-f8e9fe5e67ed","type":"LegendItem"},{"attributes":{"items":[{"id":"2f319a89-a0a3-4b89-bcc1-f8e9fe5e67ed","type":"LegendItem"},{"id":"1e44c55a-46a4-473b-814f-9755801bdfef","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"b9760ac1-8aea-4392-ba3b-8c6daab6b8ee","subtype":"Figure","type":"Plot"}},"id":"253e82e4-a6df-402d-9573-b8134a08207a","type":"Legend"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bc7e81a4-b984-4d1b-9dc4-62b0b0dc9c17","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6493e8df-3a2d-40d0-8926-aaada21e951f","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,512],"y":[0,429249.4818984265]}},"id":"abe1054e-9b55-4dee-b2b4-9b7f71e5bc38","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4f8a8e14-f455-4e9b-ab3b-5958846ef0a6","type":"ColumnDataSource"},"glyph":{"id":"6493e8df-3a2d-40d0-8926-aaada21e951f","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bc7e81a4-b984-4d1b-9dc4-62b0b0dc9c17","type":"Line"},"selection_glyph":null},"id":"4089741c-18bb-44cd-8572-9431b1b45303","type":"GlyphRenderer"},{"attributes":{"callback":null,"sizing_mode":"scale_width","tabs":[{"id":"94cf0c88-2683-48a8-89be-64622d87d921","type":"Panel"},{"id":"5fdfb1af-afa4-4c16-ad0a-ed0939858549","type":"Panel"}]},"id":"9cbff7e9-2a6a-429e-a818-4b4195e6aa66","type":"Tabs"},{"attributes":{"ticker":null},"id":"285bf36d-7215-4f6c-9fde-aeb801c924fb","type":"LogTickFormatter"},{"attributes":{"below":[{"id":"219cc51d-de70-4765-b040-da09c6f3237d","type":"LogAxis"}],"left":[{"id":"fa13208a-5efb-4e23-bdcb-08fc418a05f6","type":"LogAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"219cc51d-de70-4765-b040-da09c6f3237d","type":"LogAxis"},{"id":"a41ca008-fe7b-49b7-b1d4-e728ea472062","type":"Grid"},{"id":"fa13208a-5efb-4e23-bdcb-08fc418a05f6","type":"LogAxis"},{"id":"7272dd3f-e07a-4606-888d-e4e90196ea10","type":"Grid"},{"id":"5dcf8637-96ac-4300-a527-0d7a15e0f18d","type":"BoxAnnotation"},{"id":"253e82e4-a6df-402d-9573-b8134a08207a","type":"Legend"},{"id":"4089741c-18bb-44cd-8572-9431b1b45303","type":"GlyphRenderer"},{"id":"00171e49-09a5-4037-b336-9ad4db22910c","type":"GlyphRenderer"},{"id":"bc707042-bf62-4b86-92bf-ce1478eb9f77","type":"GlyphRenderer"},{"id":"d145e2d3-ba3c-4a97-a766-3f93bad337db","type":"GlyphRenderer"},{"id":"6c910607-9c82-4a8c-a3ec-1f915310b0fa","type":"GlyphRenderer"},{"id":"815b5641-2ba3-43f9-ba38-78a8b593201c","type":"GlyphRenderer"}],"title":{"id":"09f72566-68ed-49b5-84ce-3262d7674e9f","type":"T ...

# %% [markdown]
# ### Arrays

# %%
df[df.collection == 'arrays'].name.unique()
# Out:
# array(['blockwise 100ms tasks', 'create random', 'elementwise computation',
#        'nearest neighbor 100ms tasks', 'nearest neighbor fast tasks',
#        'random access', 'rechunk large', 'rechunk small', 'reduction',
#        'reduction along axis', 'transpose addition'], dtype=object)

# %%
fig = log_linear_plot('arrays', ['create random'], 'Arrays: Create', legends=['random'])
figures['array-create'] = fig

fig = log_linear_plot('arrays', ['elementwise computation'], 'Arrays: Elementwise', legends=['sin(x)**2 + cos(x)**2'])
figures['array-elementwise'] = fig

fig = log_linear_plot('arrays', ['reduction', 'reduction along axis'], 'Arrays: Nearest Neighbor', legends=['x.std()', 'x.std(axis=0)'])
figures['array-reductions'] = fig

fig = log_linear_plot('arrays', ['random access'], 'Arrays: Random Access', legends=['x[12345, 23456]'])
figures['array-random-access'] = fig

fig = log_linear_plot('arrays', ['transpose addition'], 'Arrays: Bulk Communication', legends=['x + x.T'])
figures['array-transpose'] = fig

fig = log_linear_plot('arrays', ['rechunk large'], 'Arrays: Rechunking', legends=['x.rechunk(...)'])
figures['array-rechunk'] = fig

fig = log_linear_plot('arrays', ['nearest neighbor 100ms tasks', 'nearest neighbor fast tasks'], 'Arrays: Map Overlap')
figures['array-overlap'] = fig

grid = [['array-create', 'array-elementwise'],
        ['array-reductions', 'array-random-access'],
        ['array-transpose', 'array-rechunk']]
grid = gridplot([[figures[name] for name in L] for L in grid], sizing_mode='scale_width')
figures['array-grid'] = grid

# %%
show(figures['array-grid'])
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1cc2788f-c990-4c9b-accb-8d27ed986cac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1cc2788f-c990-4c9b-accb-8d27ed986cac");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1cc2788f-c990-4c9b-accb-8d27ed986cac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1cc2788f-c990-4c9b-accb-8d27ed986cac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ce52e639-3cfe-4ae5-8b42-fcff4b5709d9":{"roots":{"references":[{"attributes":{"data_source":{"id":"57e6c785-0575-4a60-a51c-a30af56ed19e","type":"ColumnDataSource"},"glyph":{"id":"9179743c-1211-43e5-87d1-90cc379cbf07","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d00aff14-5599-487b-8d48-0a20840e4dd0","type":"Line"},"selection_glyph":null},"id":"7d2f2c3a-f41a-4b46-bbe6-48ada201e1d3","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#ff7f0e"},"x":{"field":"x"},"y":{"field":"y"}},"id":"684aa2f5-fc0f-410e-adcf-30e0d8518f48","type":"Line"},{"attributes":{"items":[{"id":"70ccb28b-5bed-449f-9239-0121c3c752de","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"b5e9541b-d729-4b3d-a9bb-ef1521b0e7ec","subtype":"Figure","type":"Plot"}},"id":"22520d08-d960-4c54-9490-fca030e7c1b2","type":"Legend"},{"attributes":{"label":{"value":"x.std(axis=0)"},"renderers":[{"id":"326e9923-7303-444b-9494-f61b63ca1a97","type":"GlyphRenderer"}]},"id":"bf0499f3-e84d-482f-98ca-487ae15ee390","type":"LegendItem"},{"attributes":{"child":{"id":"3607914f-5ddd-440d-8268-64817f34f711","subtype":"Figure","type":"Plot"},"title":"linear"},"id":"4264f3c0-7f6b-40b0-b364-8cfdfda249d2","type":"Panel"},{"attributes":{"items":[{"id":"fe5f8bb3-35cd-4077-9469-7a37e1e3bd5f","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"7718337a-fd9d-4212-93b6-6e12d8636449","subtype":"Figure","type":"Plot"}},"id":"29d17f4f-3bce-4581-8978-fd39e6110d7e","type":"Legend"},{"attributes":{},"id":"253a1665-c40a-4ef8-81c1-8f410d55da91","type":"BasicTickFormatter"},{"attributes":{},"id":"05682a79-d4db-4cfe-93d3-926f3a4f8b12","type":"BasicTicker"},{"attributes":{"plot":{"id":"3607914f-5ddd-440d-8268-64817f34f711","subtype":"Figure","type":"Plot"},"ticker":{"id":"05682a79-d4db-4cfe-93d3-926f3a4f8b12","type":"BasicTicker"}},"id":"6a84f683-fa31-4672-8a3f-d28473442288","type":"Grid"},{"attributes":{"overlay":{"id":"8a3211f1-5aa5-4b1e-977b-3ed41e0f005f","type":"BoxAnnotation"},"plot":{"id":"3607914f-5ddd-440d-8268-64817f34f711","subtype":"Figure","type":"Plot"}},"id":"557f3e5e-f747-49c9-b979-bfa87f526527","type":"BoxZoomTool"},{"attributes":{"axis_label":"MB/s","formatter":{"id":"73ca3439-4af2-453c-96dd-49af77189387","type":"BasicTickFormatter"},"plot":{"id":"3607914f-5ddd-440d-8268-64817f34f711","subtype":"Figure","type":"Plot"},"ticker":{"id":"11ea49cc-0362-4a82-8bcd-7db66335e868","type":"BasicTicker"}},"id":"ef86e936-482a-4a45-a989-413a74c47689","type":"LinearAxis"},{"attributes":{},"id":"11ea49cc-0362-4a82-8bcd-7db66335e868","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d00aff14-5599-487b-8d48-0a20840e4dd0","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"3607914f-5ddd-440d-8268-64817f34f711","subtype":"Figure","type":"Plot"},"ticker":{"id":"11ea49cc-0362-4a82-8bcd-7db66335e868","type":"BasicTicker"}},"id":"9977e007-93f4-4785-8b64-48cd8842fc11","type":"Grid"},{"attributes":{"num_minor_ticks":10},"id":"9c66619e-c48f-40e6-95ac-d4c8340da313","type":"LogTicker"},{"attributes":{"plot":{"id":"8743300e-a9b3-4d2d-8470-5dcc0c3a304e","subtype":"Figure","type":"Plot"},"ticker":{"id":"9c66619e-c48f-40e6-95ac-d4c8340da313","type":"LogTicker"}},"id":"3e2fd9f0-a948-4be0-8ac9-5b9b750b99da","type":"Grid"},{"attributes":{},"id":"0e7472d7-09c9-4a3f-bcb5-cf8e0885308c","type":"LogScale"},{"attributes":{"num_minor_ticks":10},"id":"b190e761-2631-45b6-9517-f18ad2c32aa7","type":"LogTicker"},{"attributes":{},"id":"330313c2-b12c-4dc6-84b8-d2228fbb63c9","type":"LogScale"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c7d51adb-0fa9-472c-a562-4d40bfc33a0f","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"8743300e-a9b3-4d2d-8470-5dcc0c3a304e","subtype":"Figure","type":"Plot"},"ticker":{"id":"b190e761-2631-45b6-9517-f18ad2c32aa7","type":"LogTicker"}},"id":"61c987d3-1b75-494c-b921-23a2 ...

# %% [markdown]
# ### Dataframes

# %%
df[df.collection == 'dataframes'].name.unique()
# Out:
# array(['arithmetic', 'blockwise 100ms tasks', 'create random',
#        'dataframe reduction', 'groupby apply (full shuffle)',
#        'groupby reduction', 'random access', 'rolling aggregations',
#        'series reduction', 'set index (full shuffle)'], dtype=object)

# %%
fig = log_linear_plot('dataframes', ['create random'], 'DataFrames: Create', legends=['random'])
figures['dataframe-create'] = fig

fig = log_linear_plot('dataframes', ['blockwise 100ms tasks', 'arithmetic'], 'DataFrames: Elementwise', legends=['100ms', 'arithmetic'])
figures['dataframe-elementwise'] = fig

fig = log_linear_plot('dataframes', ['random access'], 'DataFrames: Random Access', legends=['df.loc[123456]'])
figures['dataframe-random-access'] = fig


fig = log_linear_plot('dataframes', ['dataframe reduction', 'series reduction', 'groupby reduction'], 
                      'DataFrames: Reductions', legends=['df.std()', 'df[0].std()', 'df.groupby(0)[1].mean()'])
figures['dataframe-reductions'] = fig

fig = log_linear_plot('dataframes', ['groupby apply (full shuffle)', 'set index (full shuffle)'], 
                      'DataFrames: Full Shuffle', legends=['df.groupby(...).apply(...)', 'df.set_index(...)'])
figures['dataframe-shuffle'] = fig

fig = log_linear_plot('dataframes', ['rolling aggregations'], 'DataFrames: Time Series', legends=['df.rolling(...).mean()'])
figures['dataframe-time-series'] = fig

grid = [['dataframe-create', 'dataframe-elementwise'],
        ['dataframe-random-access', 'dataframe-reductions'],
        ['dataframe-shuffle', 'dataframe-time-series']]
grid = gridplot([[figures[name] for name in L] for L in grid], sizing_mode='scale_width')
figures['dataframe-grid'] = grid

# %%
show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bb89115-6fd1-4dd3-aae7-ac1914161f37"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0bb89115-6fd1-4dd3-aae7-ac1914161f37");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bb89115-6fd1-4dd3-aae7-ac1914161f37");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bb89115-6fd1-4dd3-aae7-ac1914161f37' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5d100740-604e-4f81-8126-ee86e21bf6b5":{"roots":{"references":[{"attributes":{},"id":"ed6dfac5-0d20-4a18-95a3-0f96a4317cdb","type":"LogScale"},{"attributes":{"axis_label":"cores","formatter":{"id":"242e4af9-5e20-4eaf-8bd5-64d5c6e96144","type":"LogTickFormatter"},"plot":{"id":"a2b40cd3-d16e-4dda-97e4-4afb68da4d7b","subtype":"Figure","type":"Plot"},"ticker":{"id":"45043c64-327e-4f3b-888c-dcf0e5c6ef32","type":"FixedTicker"}},"id":"843d8f33-2d3f-4518-b2f7-9c4e3ea235c9","type":"LogAxis"},{"attributes":{"data_source":{"id":"fe7c3259-93bc-4de1-8cb2-527af0810bed","type":"ColumnDataSource"},"glyph":{"id":"3a331fed-a5f1-4d5a-879d-258a4d178660","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3694ff40-2fac-4eee-b684-1981e54a878f","type":"Line"},"selection_glyph":null},"id":"65bfa5e4-ab78-43ad-8ba3-fd48a77949ca","type":"GlyphRenderer"},{"attributes":{"axis_label":"MB/s","formatter":{"id":"8db5adf0-f455-42b4-8d36-1354ff152315","type":"LogTickFormatter"},"plot":{"id":"a2b40cd3-d16e-4dda-97e4-4afb68da4d7b","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7a9b5d6-8e55-4ea5-a7ad-68802c32f536","type":"LogTicker"}},"id":"227c9ba6-0fbf-45eb-83bf-e6b6f0c8ea0a","type":"LogAxis"},{"attributes":{"callback":null,"sizing_mode":"scale_width","tabs":[{"id":"b39e8e65-253c-4553-8051-9f884c81e5d7","type":"Panel"},{"id":"cb8ded10-e15f-44c4-84a1-0a8236dd41bb","type":"Panel"}]},"id":"05ed764a-51a2-4bb3-ab4f-cc10ead1c269","type":"Tabs"},{"attributes":{"plot":{"id":"e9c8edb5-cf09-41f1-b9cd-b28de751b94a","subtype":"Figure","type":"Plot"}},"id":"3fc6dd28-831d-487f-925a-6eda8ad0f514","type":"HelpTool"},{"attributes":{"callback":null,"start":0},"id":"50f94427-fad9-44a0-a0ca-003edbdefcc3","type":"DataRange1d"},{"attributes":{},"id":"6ed0e2ff-2c44-41be-ad84-67be89949246","type":"ToolEvents"},{"attributes":{"children":[{"id":"31ebd17a-4a7a-4214-b942-b88b7c6fca4c","type":"Row"},{"id":"52f21c80-0fa6-4fee-be20-5fa46fa32ae4","type":"Row"},{"id":"e232961c-a359-4d06-9eba-2a194e791359","type":"Row"}],"sizing_mode":"scale_width"},"id":"b5ee82f8-f5d9-4d42-9a1c-709108f8c621","type":"Column"},{"attributes":{"child":{"id":"a2b40cd3-d16e-4dda-97e4-4afb68da4d7b","subtype":"Figure","type":"Plot"},"title":"log"},"id":"b39e8e65-253c-4553-8051-9f884c81e5d7","type":"Panel"},{"attributes":{"num_minor_ticks":10},"id":"8f9ac051-6843-4eb3-80b1-9dc60a63225e","type":"LogTicker"},{"attributes":{"items":[{"id":"ce9eeca2-30bc-49ca-b335-b9433f2a87f1","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"a2b40cd3-d16e-4dda-97e4-4afb68da4d7b","subtype":"Figure","type":"Plot"}},"id":"a34de05b-249c-442c-a19a-8ffbf118ca25","type":"Legend"},{"attributes":{"label":{"value":"random"},"renderers":[{"id":"2bd9227c-766d-4b22-9746-674d59ddedc6","type":"GlyphRenderer"}]},"id":"054637b9-f96c-478d-b2f9-6ca8ba682754","type":"LegendItem"},{"attributes":{"label":{"value":"random"},"renderers":[{"id":"b86b5e46-1543-4063-8041-7a70488dd55e","type":"GlyphRenderer"}]},"id":"ce9eeca2-30bc-49ca-b335-b9433f2a87f1","type":"LegendItem"},{"attributes":{"plot":{"id":"a2b40cd3-d16e-4dda-97e4-4afb68da4d7b","subtype":"Figure","type":"Plot"},"ticker":{"id":"8f9ac051-6843-4eb3-80b1-9dc60a63225e","type":"LogTicker"}},"id":"c72a180f-a45e-4318-b797-47835c485dc4","type":"Grid"},{"attributes":{"callback":null,"end":49937.270358022135,"start":0},"id":"0619dd5c-5936-4eab-83f0-6dfbacea9974","type":"DataRange1d"},{"attributes":{"plot":null,"text":"DataFrames: Create"},"id":"4276c7c4-db41-4d87-b5d5-88b6cbcca318","type":"Title"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6746c2a9-3c54-4c2a-8db7-0b28ab0131e4","type":"PanTool"},{"id":"85da9497-8108-47b6-80e6-9fe0e9c295f3","type":"WheelZoomTool"},{"id":"79194bfe-8ff6-485c-932b-b6f6ccadbc51","type":"BoxZoomTool"},{"id":"2edfefb9-c274-4c05-8084-4d69cbc949dc","type":"SaveTool"},{"id":"ac7d5c88-5b48-4ba8-adfa-b57888820982","type":"ResetTool"},{"id":"7a42c ...

# %%
from bokeh.embed import components

script, divs = components(list(figures.values()))

# %% [markdown]
# ```python
# with open('/home/mrocklin/workspace/blog/_posts/work/2017-06-27-scaling.md', 'at') as f:
#
#     for div in divs:
#         f.write(div)
#         f.write('\n\n')
#     f.write(script)
# ```
